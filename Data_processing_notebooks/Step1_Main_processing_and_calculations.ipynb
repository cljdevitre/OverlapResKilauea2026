# %% [markdown]
# # Main processing and calculations
# This notebook merges all new sample data together for Kilauea Pre-Post Caldera project (Ulu, 1974 SWRZ, 2020, June 2024 SWRZ and December 2024) and performs final calculations prior to plotting.
#  NOTE that at this point we have already merged Raman, SEM-EDS, SEM-EBSD and any other matrix glass data for individual samples (each in its own subdirectory of the Data_processing_notebooks folder).
# The steps are as follows:
# - 1. Import dependencies and install packages
# - 2. merge all sample datasets
# - 3. calculate SO2 mol% from Raman ratios
# - 4. Calculate T from olivine only thermometer using SEM-EDS on host olivines
# - 5. Calculate XH2O iteratively
# - 6. Calculate final P and D and uncertainty via Monte Carlo simulations
# - 7. Exports final dataset to excel for plotting in a separate notebook

# %% [markdown]
# ## 1. Import packages and setup folders and paths

# %% [markdown]
# ### Install packages if not installed

# %%
#%pip install --upgrade DiadFit
#%pip install Thermobar

# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import DiadFit as pf
import os
import pickle

# %%
pf.__version__
# Out:
# '1.0.5'

# %% [markdown]
# ### Setup folders and data paths

# %%
# This is to make sure the code runs regardless of operating system
if os.name=='posix':
    slash='/'
else:
    slash='\\'

# Set master folder
MasterFolder=os.path.dirname(os.getcwd())

# #Folder to save figures

figpath=MasterFolder +slash+"Data_processing_notebooks"+slash+'Processing Figs'
if not os.path.exists(figpath):
    os.mkdir(figpath)

# Create folder to save full datasets

compilation_folder=MasterFolder +slash+"Data_processing_notebooks"+slash+'Notebook_Compiled_data'
if not os.path.exists(compilation_folder):
    os.mkdir(compilation_folder)

# %% [markdown]
# ## 2. Merge all the datasets together

# %% [markdown]
# ### Import the Fully merged SWRZ data

# %%
KL_SWRZ=pd.read_excel(MasterFolder +slash+"Data_processing_notebooks"+slash+'Data_processing_SWRZ'+slash+'Notebook_Compiled_data'+slash+'SWRZ_Final_data_wEBSD.xlsx')

KL_SWRZ =KL_SWRZ.loc[:, ~KL_SWRZ.columns.str.contains('Unnamed')].copy()

KL_SWRZ.head()
# Out:
#                 filename  Density g/cm3  σ Density g/cm3  \
# 0           KL0919-010-A       0.119384         0.004053
# 1           KL0919-010-B       0.105191         0.008116
# 2  KL0919-010-C-meltfilm       0.090413         0.004864
# 3           KL0919-011-A       0.141729         0.004629
# 4           KL0919-011-C       0.156472         0.004005
#
#    σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                           0.001334                           0.003827
# 1                           0.007167                           0.003809
# 2                           0.003034                           0.003801
# 3                           0.002532                           0.003876
# 4                           0.000818                           0.003921
#
#    Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0           103.051548               0.003366                  0.001044
# 1           103.015728               0.018087                  0.001047
# 2           102.978432               0.007658                  0.001050
# 3           103.107941               0.006389                  0.001061
# 4           103.145147               0.002064                  0.001068
#
#    Corrected_Splitting_σ_peak_fit  power (mW)  ...  GB Length/Sqrt Size  \
# 0                        0.003205      11.971  ...                  NaN
# 1                        0.018082      11.965  ...                  NaN
# 2                        0.007596      11.966  ...                  NaN
# 3                        0.006309      11.956  ...             0.979728
# 4                        0.001769      11.954  ...             0.979728
#
#    Total GB length  Tilt length Twist length  Perc Tilt  Perc Twist  \
# 0              NaN          NaN          NaN        NaN         NaN
# 1              NaN          NaN          NaN        NaN         NaN
# 2              NaN          NaN          NaN        NaN         NaN
# 3         56.64658    50.451855      5.15671  89.064256    9.103303
# 4         56.64658    50.451855      5.15671  89.064256    9.103303
#
#    Perc unclassified  Divangle   Deformed  Day_EBSDdata
# 0                NaN       NaN        NaN           NaN
# 1                NaN       NaN        NaN           NaN
# 2                NaN       NaN        NaN           NaN
# 3            1.83244       NaN  Uncertain           1.0
# 4            1.83244       NaN  Uncertain           1.0
#
# [5 rows x 646 columns]

# %% [markdown]
# ### Import the December 2024 Data
# - Remember to update once I have EDS and EBSD

# %%
KD24=pd.read_excel(MasterFolder +slash+"Data_processing_notebooks"+slash+'Data_processing_KS24-628'+slash+'Notebook_Compiled_data'+slash+'KS24-628_Final_data_wEBSD.xlsx')
KD24 =KD24.loc[:, ~KD24.columns.str.contains('Unnamed')]

KD24.head()
# Out:
#               filename  Density g/cm3  σ Density g/cm3  \
# 0     FG04-A1-4-end_r5       0.691934         0.003428
# 1   FG04-A1-4-end-rep3       0.688868         0.004143
# 2   FG04-A1-4-start_r1       0.688678         0.004276
# 3  KD24_c001_a1_FIA_r1       0.086661         0.007504
# 4     KD24_c001_a1_FIB       0.062668         0.006605
#
#    σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                           0.002393                           0.002391
# 1                           0.003362                           0.002390
# 2                           0.003481                           0.002390
# 3                           0.006332                           0.003802
# 4                           0.005391                           0.003817
#
#    Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0           104.330131               0.004693                  0.000555
# 1           104.324111               0.006603                  0.001066
# 2           104.323735               0.006836                  0.000534
# 3           102.968963               0.015979                  0.000515
# 4           102.908411               0.013605                  0.000513
#
#    Corrected_Splitting_σ_peak_fit  power (mW)  ...  equivalentRadius (um)  \
# 0                        0.004667    6.016000  ...                    NaN
# 1                        0.006526    6.065750  ...                    NaN
# 2                        0.006827    6.001667  ...                    NaN
# 3                        0.016004    9.912000  ...             220.999032
# 4                        0.013625    9.855000  ...             220.999032
#
#    GB Length/Sqrt Size  Total GB length Tilt length Twist length  Perc Tilt  \
# 0                  NaN              NaN         NaN          NaN        NaN
# 1                  NaN              NaN         NaN          NaN        NaN
# 2                  NaN              NaN         NaN          NaN        NaN
# 3             0.125096         12.21783         0.0          0.0        0.0
# 4             0.125096         12.21783         0.0          0.0        0.0
#
#    Perc Twist  Perc unclassified  subgrain_angle  grain_div_angle
# 0         NaN                NaN             NaN              NaN
# 1         NaN                NaN             NaN              NaN
# 2         NaN                NaN             NaN              NaN
# 3         0.0                0.0             0.3              3.0
# 4         0.0                0.0             0.3              3.0
#
# [5 rows x 423 columns]

# %% [markdown]
# ### Import the 2020 Data
# - Remember to update once I have EDS and EBSD

# %%
K20=pd.read_excel(MasterFolder +slash+"Data_processing_notebooks"+slash+'Data_processing_KS20-527'+slash+'Notebook_Compiled_data'+slash+'KS20-527_Final_data_wEBSD.xlsx')
K20 =K20.loc[:, ~K20.columns.str.contains('Unnamed')]

K20.head()
# Out:
#                   filename  Density g/cm3  σ Density g/cm3  \
# 0  FG04-A1-4-100X-start_r4       0.696462         0.006099
# 1     FG04-A1-4-50X-end_r7       0.688075         0.004044
# 2   FG04-A1-4-50X-start_r1       0.690809         0.003109
# 3         FG04-A1-4-end_r4       0.694369         0.005155
# 4       FG04-A1-4-start_r1       0.693323         0.004397
#
#    σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                           0.005609                           0.002392
# 1                           0.003235                           0.002390
# 2                           0.001986                           0.002391
# 3                           0.004541                           0.002392
# 4                           0.003690                           0.002391
#
#    Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0           104.338995               0.010976                  0.001514
# 1           104.322548               0.006358                  0.001614
# 2           104.327891               0.003898                  0.001528
# 3           104.334870               0.008904                  0.000712
# 4           104.332851               0.007232                  0.000650
#
#    Corrected_Splitting_σ_peak_fit  power (mW)  ...  equivalentRadius (um)  \
# 0                        0.010895    5.984000  ...                    NaN
# 1                        0.006150    6.040000  ...                    NaN
# 2                        0.003593    5.979667  ...                    NaN
# 3                        0.008893    6.004000  ...                    NaN
# 4                        0.007218    6.092667  ...                    NaN
#
#    GB Length/Sqrt Size  Total GB length Tilt length Twist length  Perc Tilt  \
# 0                  NaN              NaN         NaN          NaN        NaN
# 1                  NaN              NaN         NaN          NaN        NaN
# 2                  NaN              NaN         NaN          NaN        NaN
# 3                  NaN              NaN         NaN          NaN        NaN
# 4                  NaN              NaN         NaN          NaN        NaN
#
#    Perc Twist  Perc unclassified  subgrain_angle  grain_div_angle
# 0         NaN                NaN             NaN              NaN
# 1         NaN                NaN             NaN              NaN
# 2         NaN                NaN             NaN              NaN
# 3         NaN                NaN             NaN              NaN
# 4         NaN                NaN             NaN              NaN
#
# [5 rows x 389 columns]

# %% [markdown]
# ### Import the old Keanakakoi, uekahuna and littoral cone data
# - I don't have EBSD or glasses on these

# %%
K21_L84_UW=pd.read_excel(MasterFolder +slash+"Data_processing_notebooks"+slash+'Data_processing_Keana_Uwe_Litt'+slash+'Notebook_Compiled_data'+slash+'Kea_Uwe_Litt_Final_data_wEBSD.xlsx')
K21_L84_UW =K21_L84_UW.loc[:, ~K21_L84_UW.columns.str.contains('Unnamed')]

K21_L84_UW.head()
# Out:
#                  filename  Density g/cm3  σ Density g/cm3  \
# 0  FO1_MI1-Oct2822postpin       0.093418         0.004147
# 1              K21-51rep1       0.136553         0.005473
# 2             K21-53-FI#4       0.017623         0.007732
# 3             K21-54-FI#2       0.102444         0.004640
# 4             K21-54-FI#4       0.068174         0.027324
#
#    σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                           0.001605                           0.003803
# 1                           0.003755                           0.003862
# 2                           0.006662                           0.003925
# 3                           0.002654                           0.003807
# 4                           0.027057                           0.003811
#
#    Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0           102.986018               0.004050                  0.000577
# 1           103.094878               0.009476                  0.000554
# 2           102.794730               0.016813                  0.000545
# 3           103.008795               0.006697                  0.000553
# 4           102.922308               0.068284                  0.000559
#
#    Corrected_Splitting_σ_peak_fit  power (mW)  ...  equivalentRadius (um)  \
# 0                        0.004014   11.974000  ...                    NaN
# 1                        0.009478   12.100333  ...                    NaN
# 2                        0.016841   19.972000  ...                    NaN
# 3                        0.006689   11.984000  ...                    NaN
# 4                        0.068433   11.973000  ...                    NaN
#
#    GB Length/Sqrt Size  Total GB length Tilt length Twist length  Perc Tilt  \
# 0                  NaN              NaN         NaN          NaN        NaN
# 1                  NaN              NaN         NaN          NaN        NaN
# 2                  NaN              NaN         NaN          NaN        NaN
# 3                  NaN              NaN         NaN          NaN        NaN
# 4                  NaN              NaN         NaN          NaN        NaN
#
#    Perc Twist  Perc unclassified  subgrain_angle  grain_div_angle
# 0         NaN                NaN             NaN              NaN
# 1         NaN                NaN             NaN              NaN
# 2         NaN                NaN             NaN              NaN
# 3         NaN                NaN             NaN              NaN
# 4         NaN                NaN             NaN              NaN
#
# [5 rows x 408 columns]

# %% [markdown]
# ### Import the other new Ulu Data
# - Remember to update to the right file (w EBSD and EDS) once I have it

# %%
KL_Ulu=pd.read_excel(MasterFolder +slash+"Data_processing_notebooks"+slash+'Data_processing_Ulu_mounts'+slash+'Notebook_Compiled_data'+slash+'Ulu_Final_data_wEBSD.xlsx')

KL_Ulu =KL_Ulu.loc[:, ~KL_Ulu.columns.str.contains('Unnamed')].copy()
KL_Ulu =KL_Ulu[~KL_Ulu['filename'].str.contains("FG|FO")]

KL_Ulu.head()
# Out:
#                  filename  Density g/cm3  σ Density g/cm3  \
# 48     KL0908_c052_a1_FIA       0.068855         0.006401
# 49     KL0908_c052_a2_FIC       0.391630         0.003477
# 50     KL0908_c054_a1_FIA       0.135271         0.010861
# 51  KL0908_c056(1)_a1_FIA       0.052341         0.005107
# 52     KL0908_c058_a1_FIA       0.135444         0.017463
#
#     σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 48                           0.005144                           0.003810
# 49                           0.002564                           0.002348
# 50                           0.010152                           0.003859
# 51                           0.003375                           0.003833
# 52                           0.017031                           0.003859
#
#     Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 48           102.924026               0.012981                  0.000816
# 49           103.695301               0.005814                  0.000820
# 50           103.091641               0.025621                  0.000810
# 51           102.882350               0.008517                  0.000805
# 52           103.092078               0.042982                  0.000792
#
#     Corrected_Splitting_σ_peak_fit  power (mW)  ...  len17  len18  len19  \
# 48                        0.012983       6.008  ...    NaN    NaN    NaN
# 49                        0.005768       6.002  ...    NaN    NaN    NaN
# 50                        0.025663       9.861  ...    NaN    NaN    NaN
# 51                        0.008497       9.880  ...    NaN    NaN    NaN
# 52                        0.043068       9.892  ...    NaN    NaN    NaN
#
#    len20 file_mod  mean_length  median_length  Perc Tilt  Perc Twist  \
# 48   NaN      NaN          NaN            NaN        0.0         0.0
# 49   NaN      NaN          NaN            NaN        0.0         0.0
# 50   NaN      NaN          NaN            NaN        0.0         0.0
# 51   NaN      NaN          NaN            NaN        0.0         0.0
# 52   NaN      NaN          NaN            NaN        0.0         0.0
#
#     Perc unclassified
# 48                0.0
# 49                0.0
# 50                0.0
# 51                0.0
# 52                0.0
#
# [5 rows x 532 columns]

# %% [markdown]
# ### Now let's merge all the datasets together
# - Eventually, at this point this means all the complete Raman+EDS+EBSD datasets for each eruption
# - Add other Ulu once I analyze
# - Filter out the standards and re-export

# %% [markdown]
# ##### I will have to make sure merging is smooth with the data that has epma can't decide if _EPMA is better or not

# %%
## Combine samples, export (includes the standards)
combo_df=pd.concat([KL_SWRZ,KD24,K20,K21_L84_UW,KL_Ulu],axis=0).dropna(axis=0,how='all').dropna(axis=1,how='all')
combo_df=combo_df.copy()
combo_df.to_excel(compilation_folder+slash+'Samples_combined_with_Standards_NoPDcalcs.xlsx')

## Filter standards and export both
standards=combo_df[combo_df['filename'].str.contains('FG|Fo|FO')].reset_index(drop=True)
combo_df=combo_df[~combo_df['filename'].str.contains('FG|Fo|FO')].reset_index(drop=True)

combo_df.to_excel(compilation_folder+slash+'Samples_combined_No_Standards_NoPDcalcs.xlsx')
standards.to_excel(compilation_folder+slash+'Standards_only_NoPDcalcs.xlsx')

combo_df.head()
# Out:
# /var/folders/r2/dcn33vbj1x1b46n5mm7vn9bc0000gn/T/ipykernel_99305/4120508378.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combo_df=pd.concat([KL_SWRZ,KD24,K20,K21_L84_UW,KL_Ulu],axis=0).dropna(axis=0,how='all').dropna(axis=1,how='all')
#                 filename  Density g/cm3  σ Density g/cm3  \
# 0           KL0919-010-A       0.119384         0.004053
# 1           KL0919-010-B       0.105191         0.008116
# 2  KL0919-010-C-meltfilm       0.090413         0.004864
# 3           KL0919-011-A       0.141729         0.004629
# 4           KL0919-011-C       0.156472         0.004005
#
#    σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                           0.001334                           0.003827
# 1                           0.007167                           0.003809
# 2                           0.003034                           0.003801
# 3                           0.002532                           0.003876
# 4                           0.000818                           0.003921
#
#    Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0           103.051548               0.003366                  0.001044
# 1           103.015728               0.018087                  0.001047
# 2           102.978432               0.007658                  0.001050
# 3           103.107941               0.006389                  0.001061
# 4           103.145147               0.002064                  0.001068
#
#    Corrected_Splitting_σ_peak_fit  power (mW)  ...  len14  len15  len16 len17  \
# 0                        0.003205      11.971  ...    NaN    NaN    NaN   NaN
# 1                        0.018082      11.965  ...    NaN    NaN    NaN   NaN
# 2                        0.007596      11.966  ...    NaN    NaN    NaN   NaN
# 3                        0.006309      11.956  ...    NaN    NaN    NaN   NaN
# 4                        0.001769      11.954  ...    NaN    NaN    NaN   NaN
#
#   len18  len19  len20  file_mod  mean_length  median_length
# 0   NaN    NaN    NaN       NaN          NaN            NaN
# 1   NaN    NaN    NaN       NaN          NaN            NaN
# 2   NaN    NaN    NaN       NaN          NaN            NaN
# 3   NaN    NaN    NaN       NaN          NaN            NaN
# 4   NaN    NaN    NaN       NaN          NaN            NaN
#
# [5 rows x 835 columns]

# %% [markdown]
# ## 3. Calculate SO2 mol % from Raman

# %%
# combo_df['SO2 mol%']=pf.calculate_mole_fraction_2comp(peak_area_a=combo_df['Peak_Area_SO2'], peak_area_b=combo_df['Diad1_Voigt_Area']+combo_df['Diad2_Voigt_Area'],
#                                   cross_section_a=5.3, cross_section_b=1.4+0.89, instrument_eff_a=1, instrument_eff_b=1)['% A']
combo_df['SO2 mol%']=pf.calculate_mole_fraction_2comp(peak_area_a=combo_df['Peak_Area_SO2'], peak_area_b=combo_df['Diad1_Voigt_Area']+combo_df['Diad2_Voigt_Area'],
                                  cross_section_a=5.791, cross_section_b=1.44+0.994, instrument_eff_a=1, instrument_eff_b=1)['% A']

# # 515 and 532 nm
# # 0.985	0.994
# # 1.428	1.440
# #combo_df['Fo']=(combo_df['MgO']/40.3044)/((combo_df['MgO']/40.3044)+(combo_df['FeOt']/71.844))
# plt.scatter(combo_df['SO2 mol%_new'],100*abs((combo_df['SO2 mol%']-combo_df['SO2 mol%_new']))/combo_df['SO2 mol%_new'])
# plt.xlabel ('SO2 mol% using new cross sections')
# plt.ylabel(r'$\frac{(SO2\ mol\%\_burke\_values - SO2\ mol\%\_new)}{SO2\ mol\%}$')

# %% [markdown]
# ## 4. Calculate the Temperature from olivine only thermometer
# - This uses the T vs Fo relationship from DeVitre and Wieser (2024) GPL for Kilauea

# %% [markdown]
# ### A. Load the Temp vs Fo correction relationship for Kilauea

# %%
with open(os.getcwd()+slash+'T and XH2O pickles'+slash+'TempFoModel.pkl', 'rb') as f:
    Pf_TempFo = pickle.load(f)

# %% [markdown]
# ### B. Calculate Temperature from Fo and plot the distribution
# - When no EDS data is available we use the mean T from the dataset (once I have other samples I can maybe do a mean per sample)
# - We establish the error on T: we use 50K+- for ones with measured Fo and 100K +- for ones we have to use a meanT for (100K is ~ the maximum 2sig T from each eruption and the whole dataset)

# %% [markdown]
# #### a. First calculate T from Fo where available. Some samples don't have Fo data so we will use a mean T for their eruption

# %%
combo_df['Temp_from_Fo_all']=Pf_TempFo(combo_df['Fo_Ol']) # Calculate T from Fo where available

# Create Temp error column, we use 50K+- for ones with measured Fo and 100K +- for ones we have to use a meanT for
#  (100K is ~ the maximum 2sig T from each eruption and the whole dataset)
combo_df['Temp_error'] = np.where(combo_df['Temp_from_Fo_all'].isna(), 100, 50)

## For samples with no Fo, we use a mean of their eruption T
combo_df['Temp_from_Fo_all'] = combo_df['Temp_from_Fo_all'].fillna(combo_df.groupby('Sample')['Temp_from_Fo_all'].transform('mean'))

## This is the mean and stdev for the whole dataset
MeanT=np.nanmean(combo_df['Temp_from_Fo_all']) # Mean of whole dataset (~1512 K)
MeanT_STD=np.nanstd(combo_df['Temp_from_Fo_all']) # STdev of whole dataset (~46K)

print("Mean T and 1sig for whole dataset: "+str(np.round(MeanT,0)) + "+-" + str(np.round(MeanT_STD,0)))
print("Std T per event: "+ str(combo_df['Sample'].unique())+str(combo_df.groupby('Sample')['Temp_from_Fo_all'].transform('std').unique()))
# Out:
# Mean T and 1sig for whole dataset: 1239.0+-46.0
# Std T per event: ['919' 'K24' 'KD24' 'K20' 'K21' 'L84' 'UW3' 'UW4' 'UW5' 'UW7' 'KL0908'
#  'KL0909' 'KL0910' 'KL0914' 'KL0916' 'KL0917' 'KL0919' 'KL0920' 'KL0921'
#  'KL0924' 'KL0930' 'KL0931'][23.6752031  30.88785777 13.29145148 35.68230871 15.03189769 48.22179128
#  75.46515107 21.61286078 35.18938006 52.57395305  9.33918678  9.04108102
#  33.53388067 20.60777643 28.21107544  3.16835002  1.52813278  5.31074034
#  13.80720069 16.02911313 22.536298   38.93942464]

# %%
## Now plot the Temp vs Fo in chronological order
import re
eruption_map = {
    r"UW": "Kulanaokuaiki \n(400-650)",
    r"K21|921": "Circ. flow\n(~1700)",
    r"L84": "Sand Hill\n(1840)",
    r"930": "Maunaiki VSWRZ\n(1919-1920)",
    r"909": "ERZ (May 1969)",
    r"908": "ERZ (Dec 1969)",
    r"916": "IC (Aug 1971)",
    r"931": "VSWRZ\n(Sep 1971)",
    r"914": "IC\n(Sep 1971)",
    r"910": "ERZ (Nov 1973)",
    r"917": "IC\n(Jul 1974)",
    r"924": "EC\n (Jul 1974)",
    r"919|920": "SSWRZ\n(Dec 1974)",
    r"K20": "IC\n(Dec 2020)",
    r"K23": "IC\n(Sept 2023)",
    r"K24": "SSWRZ\n(June 2024)",
    r"KD24": "IC\n(Dec 2024)"
}
ordered_samples = []

for pattern in eruption_map.keys():
    matches = combo_df['Sample'][
        combo_df['Sample'].astype(str).str.contains(pattern, regex=True)
    ].unique()
    ordered_samples.extend(matches)

x_positions = {sample: i for i, sample in enumerate(ordered_samples)}

# Only rows that are in the ordered list will be plotted
plot_df = combo_df[combo_df['Sample'].isin(ordered_samples)]

x = plot_df['Sample'].map(x_positions).astype(float)
x_jittered = x + np.random.normal(0, 0.15, size=len(x))

plt.figure(figsize=(12, 6))

sc = plt.scatter(x_jittered,combo_df['Temp_from_Fo_all'],
                 c=combo_df['Fo_Ol'],cmap='inferno',
                 s=40,alpha=0.7,edgecolors='k',linewidths=0.05)

plt.xticks(ticks=range(len(ordered_samples)),labels=ordered_samples,
    rotation=45,ha='right')

plt.xlabel('Sample')
plt.ylabel('T (°C)')

cbar = plt.colorbar(sc)
cbar.set_label('Fo')

plt.tight_layout()
plt.savefig(figpath + slash + 'Temp_vs_Fo_plot.pdf')
plt.show()

# %% [markdown]
# ## 5. Calculate the XH2O in the fluid inclusions
# - This uses the relationships from DeVitre and Wieser (2024) GPL
# - First we import the pickles (min, average, max - see paper for details)
# - Then we calculate a first approximation of pressure using pure CO2 EOS, and calculate a first approximation of XH2O from this pressure
# - After that we recalculate the pressure using mixed CO2-H2O EOS from Duan and Zhang 2006
# - We recalculate XH2O from this new pressure
# - We recalculate pressure and XH2O one more time to ensure it has not varied

# %% [markdown]
# ### A. First, import the pickles (polynomial relationships)

# %%
pf_files = ["PXH2O_min.pkl", "PXH2O_max.pkl", "PXH2O_av.pkl"]
Pf_functions = {}

for file_name, label in zip(pf_files, ["Pf_min", "Pf_max", "Pf_av"]):
    with open(os.path.join(os.getcwd(), "T and XH2O pickles", file_name), 'rb') as f:
        Pf_functions[label] = pickle.load(f)

Pf_min = Pf_functions["Pf_min"]
Pf_max = Pf_functions["Pf_max"]
Pf_av = Pf_functions["Pf_av"]

# And its defined as XH2O_av=1-Pf_med(P_SW96['P_MPa'])

# %% [markdown]
# ### B. Calculate the first approximation XH2O

# %% [markdown]
# #### First, calculate approximated pressure with pure CO2 EOS

# %%
combo_df['P_kbar_pureCO2_firstapprox'] =pf.calculate_P_for_rho_T(CO2_dens_gcm3=combo_df['Density g/cm3'],
                                                                        T_K=combo_df['Temp_from_Fo_all'] + 273.15,
                                                                        EOS='SW96')['P_kbar']
combo_df.head()
# Out:
#                 filename  Density g/cm3  σ Density g/cm3  \
# 0           KL0919-010-A       0.119384         0.004053
# 1           KL0919-010-B       0.105191         0.008116
# 2  KL0919-010-C-meltfilm       0.090413         0.004864
# 3           KL0919-011-A       0.141729         0.004629
# 4           KL0919-011-C       0.156472         0.004005
#
#    σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                           0.001334                           0.003827
# 1                           0.007167                           0.003809
# 2                           0.003034                           0.003801
# 3                           0.002532                           0.003876
# 4                           0.000818                           0.003921
#
#    Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0           103.051548               0.003366                  0.001044
# 1           103.015728               0.018087                  0.001047
# 2           102.978432               0.007658                  0.001050
# 3           103.107941               0.006389                  0.001061
# 4           103.145147               0.002064                  0.001068
#
#    Corrected_Splitting_σ_peak_fit  power (mW)  ...  len18  len19  len20  \
# 0                        0.003205      11.971  ...    NaN    NaN    NaN
# 1                        0.018082      11.965  ...    NaN    NaN    NaN
# 2                        0.007596      11.966  ...    NaN    NaN    NaN
# 3                        0.006309      11.956  ...    NaN    NaN    NaN
# 4                        0.001769      11.954  ...    NaN    NaN    NaN
#
#   file_mod mean_length  median_length  SO2 mol%  Temp_from_Fo_all  Temp_error  \
# 0      NaN         NaN            NaN       NaN       1311.014317          50
# 1      NaN         NaN            NaN       NaN       1311.014317          50
# 2      NaN         NaN            NaN       NaN       1311.014317          50
# 3      NaN         NaN            NaN       NaN       1315.580801          50
# 4      NaN         NaN            NaN       NaN       1315.580801          50
#
#    P_kbar_pureCO2_firstapprox
# 0                    0.389537
# 1                    0.339539
# 2                    0.288622
# 3                    0.471972
# 4                    0.527202
#
# [5 rows x 839 columns]

# %% [markdown]
# #### Next, we calculate the XH2O first approximation

# %%
# Create function to calculate XH2O from pickles that were loaded,
# If XH2O is negative we assign 0 to it
def calculate_XH2O(P_kbar, Pf_func):
    XH2O = 1 - Pf_func(P_kbar * 100)
    XH2O[XH2O < 0] = 0
    return XH2O

combo_df['XH2O_av_firstapprox'] = calculate_XH2O(combo_df['P_kbar_pureCO2_firstapprox'], Pf_av)
combo_df['XH2O_min_firstapprox'] = calculate_XH2O(combo_df['P_kbar_pureCO2_firstapprox'], Pf_min)
combo_df['XH2O_max_firstapprox'] = calculate_XH2O(combo_df['P_kbar_pureCO2_firstapprox'], Pf_max)

# %% [markdown]
# ### C. Now, we iterate calculations using mixed H2O-CO2 EOS of Duan and Zhang
# - We do 3 iterations: this means P, XH2O; P2, XH2O2;P3, XH2O final

# %%
# First we make a function to calculate iterations of P using Duan and Zhang EOS
def calculate_entrapment_pressure(df, XH2O_col):
    return pf.calculate_entrapment_P_XH2O(
        XH2O=df[XH2O_col],
        CO2_dens_gcm3=df['Density g/cm3'],
        T_K=df['Temp_from_Fo_all'] + 273.15,
        T_K_ambient=37 + 273.15,
        fast_calcs=False,
        Hloss=True
    )['P_kbar_mixCO2_DZ06_no_Hloss']

# Then we iterate 3 times to get the final XH2O
for i in range(1, 4):
    if i == 1:
        suffix = '_firstapprox'
    else:
        suffix = f'_iteration{i - 1}'

    # Calculate pressures
    combo_df[f'P_kbar_mixCO2_DZ06_no_Hloss_av_iteration{i}'] = calculate_entrapment_pressure(combo_df, f'XH2O_av{suffix}')
    combo_df[f'P_kbar_mixCO2_DZ06_no_Hloss_min_iteration{i}'] = calculate_entrapment_pressure(combo_df, f'XH2O_min{suffix}')
    combo_df[f'P_kbar_mixCO2_DZ06_no_Hloss_max_iteration{i}'] = calculate_entrapment_pressure(combo_df, f'XH2O_max{suffix}')

    # Calculate XH2O
    combo_df[f'XH2O_av_iteration{i}{"" if i < 3 else "_final"}'] = calculate_XH2O(combo_df[f'P_kbar_mixCO2_DZ06_no_Hloss_av_iteration{i}'], Pf_av)
    combo_df[f'XH2O_min_iteration{i}{"" if i < 3 else "_final"}'] = calculate_XH2O(combo_df[f'P_kbar_mixCO2_DZ06_no_Hloss_min_iteration{i}'], Pf_min)
    combo_df[f'XH2O_max_iteration{i}{"" if i < 3 else "_final"}'] = calculate_XH2O(combo_df[f'P_kbar_mixCO2_DZ06_no_Hloss_max_iteration{i}'], Pf_max)


plt.scatter(combo_df['XH2O_av_iteration3_final'],combo_df['XH2O_av_iteration3_final']-combo_df['XH2O_av_firstapprox'],label='First approx vs final')
plt.scatter(combo_df['XH2O_av_iteration3_final'],combo_df['XH2O_av_iteration3_final']-combo_df['XH2O_av_iteration1'],label='iteration1 vs final')
plt.scatter(combo_df['XH2O_av_iteration3_final'],combo_df['XH2O_av_iteration3_final']-combo_df['XH2O_av_iteration2'],label='iteration2 vs final')
plt.xlabel("XH2O final")
plt.ylabel("XH2O final-XH2O iteration")
plt.legend()
plt.savefig(figpath+slash+'XH2O_iteration.pdf')

combo_df.head()
# Out:
#                 filename  Density g/cm3  σ Density g/cm3  \
# 0           KL0919-010-A       0.119384         0.004053
# 1           KL0919-010-B       0.105191         0.008116
# 2  KL0919-010-C-meltfilm       0.090413         0.004864
# 3           KL0919-011-A       0.141729         0.004629
# 4           KL0919-011-C       0.156472         0.004005
#
#    σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                           0.001334                           0.003827
# 1                           0.007167                           0.003809
# 2                           0.003034                           0.003801
# 3                           0.002532                           0.003876
# 4                           0.000818                           0.003921
#
#    Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0           103.051548               0.003366                  0.001044
# 1           103.015728               0.018087                  0.001047
# 2           102.978432               0.007658                  0.001050
# 3           103.107941               0.006389                  0.001061
# 4           103.145147               0.002064                  0.001068
#
#    Corrected_Splitting_σ_peak_fit  power (mW)  ...  \
# 0                        0.003205      11.971  ...
# 1                        0.018082      11.965  ...
# 2                        0.007596      11.966  ...
# 3                        0.006309      11.956  ...
# 4                        0.001769      11.954  ...
#
#    P_kbar_mixCO2_DZ06_no_Hloss_max_iteration2  XH2O_av_iteration2  \
# 0                                    0.435324            0.077840
# 1                                    0.385581            0.088536
# 2                                    0.334857            0.102269
# 3                                    0.517902            0.065174
# 4                                    0.573989            0.059469
#
#    XH2O_min_iteration2 XH2O_max_iteration2  \
# 0             0.038064            0.116583
# 1             0.043628            0.132274
# 2             0.050615            0.152631
# 3             0.031243            0.098318
# 4             0.028010            0.090308
#
#   P_kbar_mixCO2_DZ06_no_Hloss_av_iteration3  \
# 0                                  0.419187
# 1                                  0.369529
# 2                                  0.318812
# 3                                  0.501296
# 4                                  0.556751
#
#    P_kbar_mixCO2_DZ06_no_Hloss_min_iteration3  \
# 0                                    0.403058
# 1                                    0.353328
# 2                                    0.302532
# 3                                    0.485004
# 4                                    0.540025
#
#    P_kbar_mixCO2_DZ06_no_Hloss_max_iteration3  XH2O_av_iteration3_final  \
# 0                                    0.436275                  0.077798
# 1                                    0.386896                  0.088466
# 2                                    0.336563                  0.102163
# 3                                    0.518385                  0.065160
# 4                                    0.574267                  0.059462
#
#    XH2O_min_iteration3_final  XH2O_max_iteration3_final
# 0                   0.038062                   0.116321
# 1                   0.043624                   0.131807
# 2                   0.050611                   0.151868
# 3                   0.031242                   0.098236
# 4                   0.028010                   0.090276
#
# [5 rows x 860 columns]

# %% [markdown]
# ## 6. Calculate final pressure and depth, propagate uncertainty and remerge

# %% [markdown]
# ### A. Calculate final pressure and depth and propagate uncertainty using Monte Carlo simulation
# - 500 duplicates
# - Duan and Zhang (2006) EOS for mixed H2O-CO2 fluids
# - CO2 density from Raman (error is sigma from DiadFit if not mean measurement, else it's standard deviation; absolute and normally distributed)
# - XH2O is used from previous step (XH2O error as the half difference between min and max XH2O, absolute and normally distributed)
# - Temperature from Forsterite content of host, or the mean of whole dataset when not available (Temperature error of +- 50K, absolute and normally distributed)
# - Denlinger-lerner crustal model in DiadFit.

# %%
# ## Before doing this, to ensure proper merging we have to create a new column in combo_df
combo_df['MCSim_filename(_date_secsincemidnight)']=combo_df['filename']+"_"+combo_df['date_object'].astype('str')+"_"+combo_df['sec since midnight'].astype('str').str.split('.').str[0]

# ## We also create a new column with the CO2 density error, 
# ## if the measurement was averaged, the error is the standard deviation ('Density g/cm3_Raman_STD') 
# ## if it's a single measurement, it's the sigma from DiadFit ('σ Density g/cm3')

combo_df['error_CO2_dens_STDifmean_σifnot'] = combo_df.apply(
    lambda row: row['Density g/cm3_Raman_STD'] if row['averaged?'] == 'Yes' else row['σ Density g/cm3'],
    axis=1
)

## Now run the simulations
MC_Av_rho_T_df_B, MC_All_rho_T_df_B, fig=pf.propagate_FI_uncertainty(
T_K=combo_df['Temp_from_Fo_all']+273.15,
error_T_K=combo_df['Temp_error'], error_type_T_K='Abs', error_dist_T_K='normal',
CO2_dens_gcm3=combo_df['Density g/cm3'],error_CO2_dens=combo_df['error_CO2_dens_STDifmean_σifnot'], 
error_type_CO2_dens='Abs', error_dist_CO2_dens='normal',
XH2O=combo_df['XH2O_av_iteration3_final'], error_XH2O=pd.Series(0.5*np.abs(combo_df['XH2O_max_iteration3_final']-combo_df['XH2O_min_iteration3_final'])), error_type_XH2O='Abs', error_dist_XH2O='normal',
sample_ID=combo_df['MCSim_filename(_date_secsincemidnight)'],
model='denlinger_lerner',
N_dup=500, fig_i=0, plot_figure=True)


fig.savefig(figpath+slash+'MCsimulation.pdf')
MC_Av_rho_T_df_B
# Out:
# You have entered a value for XH2O, so we are now using the EOS of Duan and Zhang 200 regardless of what model you selected. If you dont want this, specify XH2O=None
# Please note, the DZ2006 EOS is about 5-40X slower to run than the SP94 and SW94 EOS
# We are using multiprocessing based on your selected EOS. You can override this by setting multiprocess=False in the function, but it might slow it down a lot
# Number of processors:  8
# /opt/anaconda3/envs/py3124/lib/python3.12/site-packages/DiadFit/error_propagation.py:1162: RuntimeWarning: Mean of empty slice
#   'Mean_MC_D_km': np.nanmean(MC_T['Depth (km)']),
# /opt/anaconda3/envs/py3124/lib/python3.12/site-packages/DiadFit/error_propagation.py:1163: RuntimeWarning: All-NaN slice encountered
#   'Med_MC_D_km': np.nanmedian(MC_T['Depth (km)']),
# /opt/anaconda3/envs/py3124/lib/python3.12/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#                                     Filename      i  CO2_density_input  \
# 0             KL0919-010-A_2024-06-06_139281    0.0           0.119384
# 1             KL0919-010-B_2024-06-06_139761    1.0           0.105191
# 2    KL0919-010-C-meltfilm_2024-06-06_140092    2.0           0.090413
# 3             KL0919-011-A_2024-06-06_141180    3.0           0.141729
# 4             KL0919-011-C_2024-06-06_141923    4.0           0.156472
# ..                                       ...    ...                ...
# 527      KL0931_c034_a1_FIH_2025-04-09_45368  527.0           0.108702
# 528      KL0931_c159_a1_FIA_2025-03-20_57350  528.0           0.077921
# 529      KL0931_c160_a1_FIA_2025-03-20_57971  529.0           0.150407
# 530      KL0931_c240_a1_FIA_2025-04-01_62656  530.0           0.107876
# 531      KL0931_c240_a1_FIB_2025-04-01_62956  531.0           0.090379
#
#      SingleCalc_D_km  SingleCalc_P_kbar  Mean_MC_P_kbar  Med_MC_P_kbar  \
# 0           1.798498           0.421070        0.424479       0.422487
# 1           1.593681           0.371181        0.375359       0.373816
# 2           1.382270           0.320218        0.324010       0.322570
# 3           2.132671           0.503563        0.507036       0.505061
# 4           2.355421           0.559310        0.562758       0.560803
# ..               ...                ...             ...            ...
# 527         1.527522           0.355175        0.354344       0.351573
# 528         1.186873           0.273592        0.273497       0.271455
# 529         2.232654           0.528510        0.527786       0.527086
# 530         1.517231           0.352690        0.352742       0.350515
# 531         1.285261           0.297013        0.299517       0.297037
#
#      std_dev_MC_P_kbar  std_dev_MC_P_kbar_from_percentile  Mean_MC_D_km  ...  \
# 0             0.026950                           0.025758      1.812119  ...
# 1             0.037522                           0.035719      1.610318  ...
# 2             0.027710                           0.026446      1.397745  ...
# 3             0.029914                           0.028342      2.146265  ...
# 4             0.029983                           0.029180      2.368772  ...
# ..                 ...                                ...           ...  ...
# 527           0.043909                           0.043647      1.523257  ...
# 528           0.042857                           0.042642      1.185656  ...
# 529           0.045735                           0.045949      2.228938  ...
# 530           0.028506                           0.027834      1.517099  ...
# 531           0.038837                           0.037551      1.295089  ...
#
#        T_K_input  error_T_K  CO2_dens_gcm3_input  error_CO2_dens_gcm3  \
# 0    1584.164317       50.0             0.119384             0.004053
# 1    1584.164317       50.0             0.105191             0.008116
# 2    1584.164317       50.0             0.090413             0.004864
# 3    1588.730801       50.0             0.141729             0.004629
# 4    1588.730801       50.0             0.156472             0.004005
# ..           ...        ...                  ...                  ...
# 527  1461.796484       50.0             0.108702             0.010465
# 528  1559.097514       50.0             0.077921             0.010195
# 529  1565.935417       50.0             0.150407             0.009614
# 530  1462.511462       50.0             0.107876             0.005193
# 531  1462.511462       50.0             0.090379             0.009066
#
#      crust_dens_kgm3_input  error_crust_dens_kgm3             model   EOS  \
# 0                     None                    0.0  denlinger_lerner  DZ06
# 1                     None                    0.0  denlinger_lerner  DZ06
# 2                     None                    0.0  denlinger_lerner  DZ06
# 3                     None                    0.0  denlinger_lerner  DZ06
# 4                     None                    0.0  denlinger_lerner  DZ06
# ..                     ...                    ...               ...   ...
# 527                   None                    0.0  denlinger_lerner  DZ06
# 528                   None                    0.0  denlinger_lerner  DZ06
# 529                   None                    0.0  denlinger_lerner  DZ06
# 530                   None                    0.0  denlinger_lerner  DZ06
# 531                   None                    0.0  denlinger_lerner  DZ06
#
#      XH2O_input error_XH2O
# 0      0.077798   0.039130
# 1      0.088466   0.044091
# 2      0.102163   0.050629
# 3      0.065160   0.033497
# 4      0.059462   0.031133
# ..          ...        ...
# 527    0.092481   0.046009
# 528    0.117495   0.058135
# 529    0.062370   0.032317
# 530    0.093124   0.046315
# 531    0.109474   0.054205
#
# [532 rows x 23 columns]

# %% [markdown]
# ### B. Merge results back into the main dataframe

# %%
# First, we rename the Filename column from the simulations, to merge 
MC_Av_rho_T_df_B=MC_Av_rho_T_df_B.rename(columns={'Filename':'MCSim_filename(_date_secsincemidnight)'})

# Then we merge back in using the special filename column
combo_df_wcalcs = pd.merge(combo_df,MC_Av_rho_T_df_B, how='outer', on='MCSim_filename(_date_secsincemidnight)', suffixes=[None, 'MCSim'])
combo_df_wcalcs
# to make sure of duplicate columns can use this code: combo_df_wcalcs[combo_df_wcalcs.columns[combo_df_wcalcs.columns.str.contains('filename')]]
# Out:
#                  filename  Density g/cm3  σ Density g/cm3  \
# 0              919_50_FIA       0.141984         0.008781
# 1              919_50_FIB       0.151694         0.004892
# 2              919_51_FIA       0.191270         0.004434
# 3              919_52_FIA       0.153743         0.004916
# 4              919_52_FIB       0.143131         0.005096
# ..                    ...            ...              ...
# 527  UW7-OX6-FI#2-12mW-R1       0.134985         0.003937
# 528          UW7-OX7-FI#1       0.171994         0.003587
# 529          UW7-OX8-FI#1       0.120475         0.003967
# 530          UW7-OX8-FI#2       0.126914         0.004174
# 531          UW7-OX9-FI#1       0.143185         0.003972
#
#      σ Density g/cm3 (from Ne+peakfit)  σ Density g/cm3 (from densimeter)  \
# 0                             0.007880                           0.003876
# 1                             0.002947                           0.003905
# 2                             0.003749                           0.002369
# 3                             0.002978                           0.003912
# 4                             0.003305                           0.003879
# ..                                 ...                                ...
# 527                           0.000779                           0.003858
# 528                           0.002689                           0.002373
# 529                           0.001040                           0.003829
# 530                           0.001635                           0.003840
# 531                           0.000852                           0.003880
#
#      Corrected_Splitting  Corrected_Splitting_σ  Corrected_Splitting_σ_Ne  \
# 0             103.108584               0.019886                  0.000992
# 1             103.133089               0.007437                  0.000995
# 2             103.221905               0.009185                  0.001005
# 3             103.138260               0.007515                  0.001008
# 4             103.111478               0.008341                  0.001011
# ..                   ...                    ...                       ...
# 527           103.090919               0.001967                  0.000614
# 528           103.174533               0.006629                  0.000615
# 529           103.054301               0.002625                  0.000615
# 530           103.070551               0.004127                  0.000616
# 531           103.111614               0.002150                  0.000617
#
#      Corrected_Splitting_σ_peak_fit  power (mW)  ...    T_K_input  error_T_K  \
# 0                          0.019891    12.02700  ...  1586.067191       50.0
# 1                          0.007381    12.02100  ...  1586.067191       50.0
# 2                          0.009143    12.01800  ...  1585.870579       50.0
# 3                          0.007458    12.00900  ...  1581.879866       50.0
# 4                          0.008292    12.00600  ...  1582.911649       50.0
# ..                              ...         ...  ...          ...        ...
# 527                        0.001871     9.06175  ...  1578.825924       50.0
# 528                        0.006614    12.00500  ...  1516.338771       50.0
# 529                        0.002557    12.01200  ...  1481.912994       50.0
# 530                        0.004090    12.02500  ...  1481.912994       50.0
# 531                        0.002064    12.04400  ...  1608.330671       50.0
#
#      CO2_dens_gcm3_input error_CO2_dens_gcm3 crust_dens_kgm3_input  \
# 0               0.141984            0.008781                  None
# 1               0.151694            0.004892                  None
# 2               0.191270            0.004434                  None
# 3               0.153743            0.004916                  None
# 4               0.143131            0.005096                  None
# ..                   ...                 ...                   ...
# 527             0.134985            0.002217                  None
# 528             0.171994            0.003587                  None
# 529             0.120475            0.003967                  None
# 530             0.126914            0.004174                  None
# 531             0.143185            0.003972                  None
#
#      error_crust_dens_kgm3             model   EOS  XH2O_input  error_XH2O
# 0                      0.0  denlinger_lerner  DZ06    0.065145    0.033490
# 1                      0.0  denlinger_lerner  DZ06    0.061202    0.031835
# 2                      0.0  denlinger_lerner  DZ06    0.051709    0.028335
# 3                      0.0  denlinger_lerner  DZ06    0.060602    0.031591
# 4                      0.0  denlinger_lerner  DZ06    0.064755    0.033323
# ..                     ...               ...   ...         ...         ...
# 527                    0.0  denlinger_lerner  DZ06    0.068803    0.035080
# 528                    0.0  denlinger_lerner  DZ06    0.057018    0.030187
# 529                    0.0  denlinger_lerner  DZ06    0.082338    0.041236
# 530                    0.0  denlinger_lerner  DZ06    0.078040    0.039251
# 531                    0.0  denlinger_lerner  DZ06    0.063815    0.032931
#
# [532 rows x 884 columns]

# %% [markdown]
# ## 7. Final data export for plotting

# %%
combo_df_wcalcs.to_excel(compilation_folder+slash+'FinalNewDataset.xlsx')
